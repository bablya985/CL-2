# %%
pip install -U pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\shrad\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: networkx in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (1.26.4)
# Requirement already satisfied: scipy in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (1.5.1)
# Requirement already satisfied: pandas in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (2.2.2)
# Requirement already satisfied: torch in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (2.9.0)
# Requirement already satisfied: statsmodels in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (4.66.5)
# Requirement already satisfied: joblib in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\shrad\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrad\anaconda3\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrad\anaconda3\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrad\anaconda3\lib\site-packages (from pandas->pgmpy) (2023.3)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\shrad\anaconda3\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\shrad\anaconda3\lib\site-packages (from torch->pgmpy) (75.1.0)
# Requirement already satisfied: colorama in c:\users\shrad\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shrad\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\shrad\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\shrad\anaconda3\lib\site-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: six in c:\users\shrad\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shrad\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrad\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination

# %%
heartDisease = pd.read_csv(r"C:\Users\shrad\Downloads\heart.csv")
heartDisease = heartDisease.replace('?', np.nan)

# %%
print('Few examples from the dataset are given below:')
print(heartDisease.head())
# Out:
# Few examples from the dataset are given below:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Define model using correct column names
model = DiscreteBayesianNetwork([
    ('age', 'trestbps'),
    ('age', 'fbs'),
    ('sex', 'trestbps'),
    ('exang', 'trestbps'),
    ('trestbps', 'target'),
    ('fbs', 'target'),
    ('target', 'restecg'),
    ('target', 'thalach'),
    ('target', 'chol')
])

# %%
print('\nLearning CPDs using Maximum Likelihood Estimators...')
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'age': 'N', 'sex': 'N', 'cp': 'N', 'trestbps': 'N', 'chol': 'N', 'fbs': 'N', 'restecg': 'N', 'thalach': 'N', 'exang': 'N', 'oldpeak': 'N', 'slope': 'N', 'ca': 'N', 'thal': 'N', 'target': 'N'}
# Learning CPDs using Maximum Likelihood Estimators...

# %%
print('\nInferencing with Bayesian Network:')
HeartDisease_infer = VariableElimination(model)
# Out:
# Inferencing with Bayesian Network:

# %%
print('\n1. Probability of target (heart disease) given Age = 29')
q = HeartDisease_infer.query(variables=['target'], evidence={'age': 29})
print(q)
# Out:
# 1. Probability of target (heart disease) given Age = 29
# +-----------+---------------+
# | target    |   phi(target) |
# +===========+===============+
# | target(0) |        0.4019 |
# +-----------+---------------+
# | target(1) |        0.5981 |
# +-----------+---------------+

# %%
print('\n2. Probability of target (heart disease) given Cholesterol = 126')
q = HeartDisease_infer.query(variables=['target'], evidence={'chol': 126})
print(q)
# Out:
# 2. Probability of target (heart disease) given Cholesterol = 126
# +-----------+---------------+
# | target    |   phi(target) |
# +===========+===============+
# | target(0) |        0.0000 |
# +-----------+---------------+
# | target(1) |        1.0000 |
# +-----------+---------------+
